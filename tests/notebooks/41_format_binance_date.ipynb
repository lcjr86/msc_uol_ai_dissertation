# %%
import os
import pandas as pd
import datetime as dt

# %%
input_data_path = '../data'
input_data_filename = 'binance_BTCUSDT_15m_from_2020_01_01_to_2021_12_31_candlesticks_signals_processed_technical_indicators_and_crypto_index'
input_data_extension = ".csv"
full_path_input_data = os.path.join(input_data_path, input_data_filename + input_data_extension)

# %%
df = pd.read_csv(full_path_input_data)

# %%
df.head()
# Out:
#        open_time     open     high      low    close      volume  \
# 0  1577944800000  7138.93  7144.98  7135.00  7138.90  154.330095
# 1  1577945700000  7138.90  7149.00  7138.50  7146.58  178.369024
# 2  1577946600000  7145.96  7149.02  7136.41  7136.81  142.773244
# 3  1577947500000  7136.42  7139.14  7121.43  7135.97  212.128302
# 4  1577948400000  7136.04  7140.63  7121.01  7125.26  243.045551
#
#       close_time  quote_asset_volumne  number_of_trades  \
# 0  1577945699999         1.101881e+06              1732
# 1  1577946599999         1.274135e+06              1738
# 2  1577947499999         1.019787e+06              1650
# 3  1577948399999         1.512872e+06              2549
# 4  1577949299999         1.732451e+06              2848
#
#    taker_buy_base_asset_volume  ...     BBANDS_L          AD        ATR  \
# 0                    72.727343  ...  7119.218729 -171.772047  16.210334
# 1                   112.015625  ...  7120.381609  -75.622649  15.802453
# ...

# %%
df['datetime'] = df.open_time.apply(lambda x: dt.datetime.fromtimestamp(x / 1000.0))

# %%
df.head()
# Out:
#        open_time     open     high      low    close      volume  \
# 0  1577944800000  7138.93  7144.98  7135.00  7138.90  154.330095
# 1  1577945700000  7138.90  7149.00  7138.50  7146.58  178.369024
# 2  1577946600000  7145.96  7149.02  7136.41  7136.81  142.773244
# 3  1577947500000  7136.42  7139.14  7121.43  7135.97  212.128302
# 4  1577948400000  7136.04  7140.63  7121.01  7125.26  243.045551
#
#       close_time  quote_asset_volumne  number_of_trades  \
# 0  1577945699999         1.101881e+06              1732
# 1  1577946599999         1.274135e+06              1738
# 2  1577947499999         1.019787e+06              1650
# 3  1577948399999         1.512872e+06              2549
# 4  1577949299999         1.732451e+06              2848
#
#    taker_buy_base_asset_volume  ...          AD        ATR      HT_DC  \
# 0                    72.727343  ... -171.772047  16.210334  25.653704
# 1                   112.015625  ...  -75.622649  15.802453  27.065789
# ...

# %%
date_value = df['datetime'].apply(lambda x: x.strftime('%Y-%m-%d %H:%M:%S'))
df.insert(0, 'time', date_value)

# %%
df.head()
# Out:
#                   time      open_time     open     high      low    close  \
# 0  2020-01-02 07:00:00  1577944800000  7138.93  7144.98  7135.00  7138.90
# 1  2020-01-02 07:15:00  1577945700000  7138.90  7149.00  7138.50  7146.58
# 2  2020-01-02 07:30:00  1577946600000  7145.96  7149.02  7136.41  7136.81
# 3  2020-01-02 07:45:00  1577947500000  7136.42  7139.14  7121.43  7135.97
# 4  2020-01-02 08:00:00  1577948400000  7136.04  7140.63  7121.01  7125.26
#
#        volume     close_time  quote_asset_volumne  number_of_trades  ...  \
# 0  154.330095  1577945699999         1.101881e+06              1732  ...
# 1  178.369024  1577946599999         1.274135e+06              1738  ...
# 2  142.773244  1577947499999         1.019787e+06              1650  ...
# 3  212.128302  1577948399999         1.512872e+06              2549  ...
# 4  243.045551  1577949299999         1.732451e+06              2848  ...
#
#            AD        ATR      HT_DC          SAR ratio_high_open  \
# ...

# %%
df[df.duplicated(['time'])]
# Out:
# Empty DataFrame
# ...

# %%
df = df.drop_duplicates('time')

# %%
export_path = "../data"
export_filename = 'binance_BTCUSDT_15m_from_2020_01_01_to_2021_12_31_candlesticks_signals_processed_technical_indicators_and_crypto_index_v2'
export_extension = ".csv"
full_export_path = os.path.join(export_path, export_filename + export_extension)

# %%
df.to_csv(full_export_path, index=False)
