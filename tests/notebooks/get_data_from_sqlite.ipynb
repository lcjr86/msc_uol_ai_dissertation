# %%
import sqlite3
from sqlalchemy import create_engine
import pandas as pd
import datetime

# %%
db_address = 'sqlite:///../../data/db/crypto.db'
asset_ticket = 'BTCUSDT'
timestamp = '1d'

# %%
engine = create_engine(db_address, echo=True)
sqlite_connection = engine.connect()

# %%
input_tbl_name = "tbl_raw_binance" + "_" + asset_ticket + "_" + timestamp

sql_command = "SELECT * FROM " + input_tbl_name

df = pd.read_sql(sql_command, sqlite_connection)
# Out:
# 2023-01-18 13:34:08,335 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM tbl_raw_binance_BTCUSDT_1d")
# 2023-01-18 13:34:08,335 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-01-18 13:34:08,336 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM tbl_raw_binance_BTCUSDT_1d")
# 2023-01-18 13:34:08,337 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-01-18 13:34:08,337 INFO sqlalchemy.engine.Engine SELECT * FROM tbl_raw_binance_BTCUSDT_1d
# 2023-01-18 13:34:08,338 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
df
# Out:
#           open_time      open      high       low     close         volume  \
# 0     1502928000000   4261.48   4485.39   4200.74   4285.08     795.150377
# 1     1503014400000   4285.08   4371.52   3938.77   4108.37    1199.888264
# 2     1503100800000   4108.37   4184.69   3850.00   4139.98     381.309763
# 3     1503187200000   4120.98   4211.08   4032.62   4086.29     467.083022
# 4     1503273600000   4069.13   4119.62   3911.79   4016.00     691.743060
# ...             ...       ...       ...       ...       ...            ...
# 1959  1672185600000  16706.06  16785.19  16465.33  16547.31  193037.565770
# 1960  1672272000000  16547.32  16664.41  16488.91  16633.47  160998.471580
# 1961  1672358400000  16633.47  16677.35  16333.00  16607.48  164916.311740
# 1962  1672444800000  16607.48  16644.09  16470.00  16542.40  114490.428640
# 1963  1672531200000  16541.77  16628.00  16499.01  16616.75   96925.413740
#
#          close_time  quote_asset_volume  number_of_trades  \
# 0     1503014399999        3.454770e+06              3427
# 1     1503100799999        5.086958e+06              5233
# 2     1503187199999        1.549484e+06              2153
# 3     1503273599999        1.930364e+06              2321
# 4     1503359999999        2.797232e+06              3972
# ...             ...                 ...               ...
# 1959  1672271999999        3.210894e+09           5465468
# 1960  1672358399999        2.671666e+09           4553877
# 1961  1672444799999        2.726831e+09           4310415
# 1962  1672531199999        1.897048e+09           3344374
# 1963  1672617599999        1.604794e+09           3218355
#
#       taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ignore  \
# 0                      616.248541                  2.678216e+06       0
# 1                      972.868710                  4.129123e+06       0
# 2                      274.336042                  1.118002e+06       0
# 3                      376.795947                  1.557401e+06       0
# 4                      557.356107                  2.255663e+06       0
# ...                           ...                           ...     ...
# 1959                 96118.187170                  1.598768e+09       0
# 1960                 80977.624430                  1.343800e+09       0
# 1961                 82170.474900                  1.358631e+09       0
# 1962                 57021.069190                  9.448344e+08       0
# 1963                 48548.781680                  8.038417e+08       0
#
#              formatted_open_time        formatted_close_time  \
# 0     2017-08-17 00:00:00.000000  2017-08-17 23:59:59.999000
# 1     2017-08-18 00:00:00.000000  2017-08-18 23:59:59.999000
# 2     2017-08-19 00:00:00.000000  2017-08-19 23:59:59.999000
# 3     2017-08-20 00:00:00.000000  2017-08-20 23:59:59.999000
# 4     2017-08-21 00:00:00.000000  2017-08-21 23:59:59.999000
# ...                          ...                         ...
# 1959  2022-12-28 00:00:00.000000  2022-12-28 23:59:59.999000
# 1960  2022-12-29 00:00:00.000000  2022-12-29 23:59:59.999000
# 1961  2022-12-30 00:00:00.000000  2022-12-30 23:59:59.999000
# 1962  2022-12-31 00:00:00.000000  2022-12-31 23:59:59.999000
# 1963  2023-01-01 00:00:00.000000  2023-01-01 23:59:59.999000
#
#                             date  upper_shadow  lower_shadow  real_body
# 0     2017-08-18 00:00:00.000000        200.31         60.74      23.60
# 1     2017-08-19 00:00:00.000000         86.44        169.60     176.71
# 2     2017-08-20 00:00:00.000000         44.71        258.37      31.61
# 3     2017-08-21 00:00:00.000000         90.10         53.67      34.69
# 4     2017-08-22 00:00:00.000000         50.49        104.21      53.13
# ...                          ...           ...           ...        ...
# 1959  2022-12-29 00:00:00.000000         79.13         81.98     158.75
# 1960  2022-12-30 00:00:00.000000         30.94         58.41      86.15
# 1961  2022-12-31 00:00:00.000000         43.88        274.48      25.99
# 1962  2023-01-01 00:00:00.000000         36.61         72.40      65.08
# 1963  2023-01-02 00:00:00.000000         11.25         42.76      74.98
#
# [1964 rows x 18 columns]

# %%
start_date = "1 Jan, 2022"
end_date = "2 Jan, 2022"

# %%
input_tbl_name = "tbl_raw_binance" + "_" + asset_ticket + "_" + timestamp

sql_command = "SELECT * FROM " + input_tbl_name

if(start_date!="" and end_date!=""):
    
    sd = datetime.datetime.strptime(start_date,'%d %b, %Y').strftime('%Y-%m-%d')
    sd_dt = datetime.datetime.strptime(sd,'%Y-%m-%d')
    sd_dt = sd_dt + datetime.timedelta(days=-180)
    sd = sd_dt.strftime('%Y-%m-%d')
    ed = datetime.datetime.strptime(end_date,'%d %b, %Y').strftime('%Y-%m-%d')

    sql_append = " WHERE " + "date(date) >= " + "'" + sd + "'" + " AND date(date) <= " + "'" + ed + "'"
    sql_command = sql_command + sql_append
# Out:
# 2021-07-05
# 2022-01-02

# %%
df = pd.read_sql(sql_command, sqlite_connection)
# Out:
# 2023-01-18 13:42:35,427 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM tbl_raw_binance_BTCUSDT_1d WHERE date(date) >= '2021-07-05' AND date(date) <= '2022-01-02'")
# 2023-01-18 13:42:35,428 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-01-18 13:42:35,429 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM tbl_raw_binance_BTCUSDT_1d WHERE date(date) >= '2021-07-05' AND date(date) <= '2022-01-02'")
# 2023-01-18 13:42:35,430 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-01-18 13:42:35,430 INFO sqlalchemy.engine.Engine SELECT * FROM tbl_raw_binance_BTCUSDT_1d WHERE date(date) >= '2021-07-05' AND date(date) <= '2022-01-02'
# 2023-01-18 13:42:35,431 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
df
# Out:
#          open_time      open      high       low     close        volume  \
# 0    1625356800000  34669.12  35967.85  34357.15  35286.51  43703.475789
# 1    1625443200000  35288.13  35293.78  33125.55  33690.14  64123.874245
# 2    1625529600000  33690.15  35118.88  33532.00  34220.01  58210.596349
