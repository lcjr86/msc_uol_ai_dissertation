# %% [markdown]
# # Get Candlestick Patterns

# %% [markdown]
# ## Import relevant libraries

# %%
import os
import pandas as pd
import talib
import mplfinance as mpf
import numpy as np
import matplotlib.pyplot as plt
import datetime
from configparser import ConfigParser

# %%
configur = ConfigParser()
print (configur.read('../../config_files/config_candlestick_patterns.ini'))
#print ("Sections : ", configur.sections())
# Out:
# ['../../config_files/config_candlestick_patterns.ini']

# %% [markdown]
# ## Get the data

# %% [markdown]
# ### Parameters

# %%
asset_ticket = "BTCUSDT"
timestamp = "1d"
start_date = "1 Jan, 2017"
end_date = "31 Dec, 2022"

# %%
input_data_path = '../../../data/05_raw_group'
input_data_filename = "binance" + \
                  "_" + asset_ticket + \
                  "_" + timestamp + \
                  "_from_" + datetime.datetime.strptime(start_date,'%d %b, %Y').strftime('%Y_%m_%d') + \
                  "_to_" + datetime.datetime.strptime(end_date,'%d %b, %Y').strftime('%Y_%m_%d')
input_data_extension = ".csv"
full_path_input_data = os.path.join(input_data_path, input_data_filename + input_data_extension)

# %%
df = pd.read_csv(full_path_input_data)

# %%
df.columns
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'quote_asset_volumne', 'number_of_trades',
#        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore',
#        'formatted_open_time', 'formatted_close_time', 'upper_shadow',
#        'lower_shadow', 'real_body'],
#       dtype='object')

# %% [markdown]
# ## Identify Candlestick Patterns

# %%
candle_names = talib.get_function_groups()['Pattern Recognition']

# %% [markdown]
# - Inverted Hammer --> Single [Bullish]
# - Hammer --> Single [Bullish]
# - Bullish Engulfing (not available at ta-lib) --> Double [Bullish]
# - Piercing Pattern --> Double [Bullish]
# - Morning Star --> Triple [Bullish]
#
#
# - Shooting Star --> Single [Bearish]
# - Hanging Man --> Single [Bearish]
# - Bearish Engulfing (not available at ta-lib) --> Double [Bearish]
# - Dark Cloud Cover --> Double [Bearish]
# - Evening Star --> Triple [Bearish]
#
# - Engulfing [positive: Bullish / negative: Bearish]

# %%
candle_names = [
    'CDLINVERTEDHAMMER',
    'CDLHAMMER',
    'CDLPIERCING',
    'CDLMORNINGSTAR',
    'CDLSHOOTINGSTAR',
    'CDLHANGINGMAN',
    'CDLDARKCLOUDCOVER',
    'CDLEVENINGSTAR',
    'CDLENGULFING'
]

# %%
# extract OHLC 
op = df['open']
hi = df['high']
lo = df['low']
cl = df['close']

# create columns for each pattern
for candle in candle_names:
    # below is same as;
    # df["CDL3LINESTRIKE"] = talib.CDL3LINESTRIKE(op, hi, lo, cl)
    df[candle] = getattr(talib, candle)(op, hi, lo, cl)

# %%
df.sample(10)
# Out:
#           open_time      open      high       low     close         volume  \
# 1702  1651276800000  38596.11  38795.38  37578.20  37630.80   35321.189890
# 50    1508544000000   6013.72   6171.00   5850.03   6024.97    1664.307693
# 729   1567209600000   9582.76   9684.51   9420.75   9587.47   17130.290074
# 1393  1624579200000  34663.08  35500.00  31275.00  31584.45  116061.130356
# 999   1590537600000   8841.00   9225.00   8811.73   9204.07   68910.355514
# 489   1546473600000   3857.57   3862.74   3730.00   3766.78   29406.948359
# 931   1584662400000   6162.05   6900.00   5670.00   6208.36  219298.329514
# 1350  1620864000000  49537.15  51367.19  46000.00  49670.97  147332.002121
# 1075  1597104000000  11892.90  11935.00  11125.00  11392.08   90748.284634
# 750   1569024000000  10167.92  10176.70   9900.00   9986.39   20544.175196
#
#          close_time  quote_asset_volumne  number_of_trades  \
# 1702  1651363199999         1.354901e+09           1017369
# 50    1508630399999         1.011482e+07             10182
# 729   1567295999999         1.641168e+08            199188
# 1393  1624665599999         3.846121e+09           2094932
# 999   1590623999999         6.246609e+08            662850
# 489   1546559999999         1.116574e+08            199812
# 931   1584748799999         1.401734e+09           1580069
# 1350  1620950399999         7.303695e+09           3570506
# 1075  1597190399999         1.049616e+09           1343979
# 750   1569110399999         2.060340e+08            245439
#
#       taker_buy_base_asset_volume  ...  real_body  CDLINVERTEDHAMMER  \
# 1702                 16523.430170  ...     965.31                  0
# 50                     796.022575  ...      11.25                  0
# 729                   8558.148214  ...       4.71                  0
# 1393                 55656.156252  ...    3078.63                  0
# 999                  33532.620265  ...     363.07                  0
# 489                  14793.083267  ...      90.79                  0
# 931                 104719.639180  ...      46.31                  0
# 1350                 71742.003359  ...     133.82                  0
# 1075                 41221.961009  ...     500.82                  0
# 750                   9285.851479  ...     181.53                  0
#
#      CDLHAMMER CDLPIERCING  CDLMORNINGSTAR  CDLSHOOTINGSTAR  CDLHANGINGMAN  \
# 1702         0           0               0                0              0
# 50           0           0               0                0              0
# 729          0           0               0                0              0
# 1393         0           0               0                0              0
# 999          0           0               0                0              0
# 489          0           0               0                0              0
# 931          0           0               0                0              0
# 1350         0           0               0                0              0
# 1075         0           0               0                0              0
# 750          0           0               0                0              0
#
#       CDLDARKCLOUDCOVER  CDLEVENINGSTAR  CDLENGULFING
# 1702                  0               0             0
# 50                    0               0             0
# 729                   0               0             0
# 1393                  0               0             0
# 999                   0               0           100
# 489                   0               0             0
# 931                   0               0             0
# 1350                  0               0             0
# 1075                  0               0             0
# 750                   0               0             0
#
# [10 rows x 26 columns]

# %% [markdown]
# ## Split 'CDLENGULFING' into Bullish and Bearish one

# %%
list_open_time_bullish_engulfing = df[df['CDLENGULFING']==100]['date'].to_list()
list_open_time_bearish_engulfing = df[df['CDLENGULFING']==-100]['date'].to_list()

# %%
df['CDLENGULFINGBULLISH'] = np.where(df['date'].isin(list_open_time_bullish_engulfing), 100, 0)
df['CDLENGULFINGBEARISH'] = np.where(df['date'].isin(list_open_time_bearish_engulfing), -100, 0)

# %% [markdown]
# ### Check

# %%
df[df['CDLENGULFING']==100].sample(5)
# Out:
#           open_time      open      high       low     close        volume  \
# 58    1509235200000   5709.98   6189.88   5648.01   6169.98   1804.778173
# 1088  1598227200000  11648.12  11824.90  11585.09  11748.20  46212.391867
# 1245  1611792000000  30362.19  33783.98  29842.10  33364.86  92621.145617
# 1277  1614556800000  45134.11  49790.00  44950.53  49587.03  85086.111648
# 960   1587168000000   7026.78   7293.08   7014.40   7248.60  49488.542819
#
#          close_time  quote_asset_volumne  number_of_trades  \
# 58    1509321599999         1.062097e+07             10651
# 1088  1598313599999         5.422990e+08            656584
# 1245  1611878399999         2.953553e+09           2060660
# 1277  1614643199999         4.057516e+09           2147223
# 960   1587254399999         3.548451e+08            494670
#
#       taker_buy_base_asset_volume  ...  CDLHAMMER  CDLPIERCING CDLMORNINGSTAR  \
# 58                     954.170196  ...          0            0              0
# 1088                 22780.419488  ...          0            0              0
# 1245                 46067.782326  ...          0            0              0
# 1277                 42616.994361  ...          0            0              0
# 960                  23980.644731  ...          0            0              0
#
#      CDLSHOOTINGSTAR  CDLHANGINGMAN  CDLDARKCLOUDCOVER  CDLEVENINGSTAR  \
# 58                 0              0                  0               0
# 1088               0              0                  0               0
# 1245               0              0                  0               0
# 1277               0              0                  0               0
# 960                0              0                  0               0
#
#       CDLENGULFING  CDLENGULFINGBULLISH  CDLENGULFINGBEARISH
# 58             100                  100                    0
# 1088           100                  100                    0
# 1245           100                  100                    0
# 1277           100                  100                    0
# 960            100                  100                    0
#
# [5 rows x 28 columns]

# %%
df[df['CDLENGULFING']==-100].sample(5)
# Out:
#           open_time      open      high       low     close         volume  \
# 1389  1624233600000  35600.17  35750.00  31251.23  31608.93  168778.873159
# 1713  1652227200000  31017.11  32162.59  27785.00  29103.94  207063.739278
# 1273  1614211200000  49676.21  52041.73  46674.34  47073.73   83310.673121
# 506   1547942400000   3665.75   3693.73   3475.00   3539.28   27901.938598
# 468   1544659200000   3446.38   3460.00   3255.50   3302.06   40040.917013
#
#          close_time  quote_asset_volumne  number_of_trades  \
# 1389  1624319999999         5.545926e+09           2688993
# 1713  1652313599999         6.300296e+09           3559270
# 1273  1614297599999         4.152189e+09           2305679
# 506   1548028799999         9.976724e+07            204941
# 468   1544745599999         1.348171e+08            160471
#
#       taker_buy_base_asset_volume  ...  CDLHAMMER  CDLPIERCING CDLMORNINGSTAR  \
# 1389                 81297.469751  ...          0            0              0
# 1713                 99622.117475  ...          0            0              0
# 1273                 40610.664759  ...          0            0              0
# 506                  13875.111381  ...          0            0              0
# 468                  19671.315079  ...          0            0              0
#
#      CDLSHOOTINGSTAR  CDLHANGINGMAN  CDLDARKCLOUDCOVER  CDLEVENINGSTAR  \
# 1389               0              0                  0               0
# 1713               0              0                  0               0
# 1273               0              0                  0               0
# 506                0              0                  0               0
# 468                0              0                  0               0
#
#       CDLENGULFING  CDLENGULFINGBULLISH  CDLENGULFINGBEARISH
# 1389          -100                    0                 -100
# 1713          -100                    0                 -100
# 1273          -100                    0                 -100
# 506           -100                    0                 -100
# 468           -100                    0                 -100
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'quote_asset_volumne', 'number_of_trades',
#        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore',
#        'formatted_open_time', 'formatted_close_time', 'upper_shadow',
#        'lower_shadow', 'real_body', 'CDLINVERTEDHAMMER', 'CDLHAMMER',
#        'CDLPIERCING', 'CDLMORNINGSTAR', 'CDLSHOOTINGSTAR', 'CDLHANGINGMAN',
#        'CDLDARKCLOUDCOVER', 'CDLEVENINGSTAR', 'CDLENGULFING',
#        'CDLENGULFINGBULLISH', 'CDLENGULFINGBEARISH'],
#       dtype='object')

# %% [markdown]
# ## Replace first (based on the 'window_size') Candlestick values for 0

# %%
window_size = configur.getint('candlestick_patterns', 'window_size')

# %%
subset = ['CDLINVERTEDHAMMER', 'CDLHAMMER',
       'CDLPIERCING', 'CDLMORNINGSTAR', 'CDLSHOOTINGSTAR', 'CDLHANGINGMAN',
       'CDLDARKCLOUDCOVER', 'CDLEVENINGSTAR', 'CDLENGULFING',
       'CDLENGULFINGBULLISH', 'CDLENGULFINGBEARISH']

df.loc[:window_size, subset] = df.loc[:window_size, subset].replace([100, -100],[0, 0])

# %% [markdown]
# ## Export the Data

# %% [markdown]
# ### Export parameters

# %%
export_path = "../../../data/10_candlesticks_signals_raw"
export_filename = "binance" + \
                  "_" + asset_ticket + \
                  "_" + timestamp + \
                  "_from_" + datetime.datetime.strptime(start_date,'%d %b, %Y').strftime('%Y_%m_%d') + \
                  "_to_" + datetime.datetime.strptime(end_date,'%d %b, %Y').strftime('%Y_%m_%d') + \
                  "_candlesticks_signals_raw"
export_extension = ".csv"
full_export_path = os.path.join(export_path, export_filename + export_extension)

# %% [markdown]
# ### Export

# %%
df.to_csv(full_export_path, index=False)
