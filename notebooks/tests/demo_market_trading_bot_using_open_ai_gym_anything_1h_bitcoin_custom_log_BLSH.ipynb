# %% [markdown]
# ## BLSH = Buy Low Sell High

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Dependencies
import gym
import gym_anytrading

from gym_anytrading.envs import StocksEnvLogBLSH

# %%
# Stable baselines - rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C

# %%
# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.8.1

# %%
import quantstats as qs

# %%
#loading our dataset
df = pd.read_csv('../../data/binance_BTCUSDT_1h_from_2020_01_01_to_2022_09_30_candlesticks_signals_processed_technical_indicators_and_crypto_index.csv')
#viewing first 5 columns
df.head()
# Out:
#        open_time     open     high      low    close       volume  \
# 0  1578268800000  7357.64  7384.72  7346.76  7378.75  1358.867787
# 1  1578272400000  7378.97  7426.82  7368.55  7423.50  1630.227541
# 2  1578276000000  7423.06  7562.00  7421.64  7551.44  5819.256972
# 3  1578279600000  7551.47  7580.00  7486.85  7540.90  4769.906356
# 4  1578283200000  7540.90  7554.61  7516.06  7529.52  1554.582461
#
#       close_time  quote_asset_volumne  number_of_trades  \
# 0  1578272399999         1.000665e+07             10399
# 1  1578275999999         1.204807e+07             14099
# 2  1578279599999         4.366371e+07             38256
# 3  1578283199999         3.593969e+07             27817
# 4  1578286799999         1.171094e+07             13475
#
#    taker_buy_base_asset_volume  ...     BBANDS_L            AD        ATR  \
# 0                   712.183975  ...  7358.112084  19912.415403  42.216983
# 1                   917.223564  ...  7357.755635  21356.874781  43.363627
# 2                  3402.178628  ...  7344.217387  26300.506879  50.291939
# 3                  2222.120771  ...  7336.567145  27066.047406  53.353229
# 4                   854.354945  ...  7333.356615  26597.051452  52.295856
#
#        HT_DC          SAR  ratio_high_open  ratio_low_open  ratio_close_open  \
# 0  18.324288  7466.008435         1.003681        0.998521          1.002869
# 1  17.869168  7457.127929         1.006485        0.998588          1.006035
# 2  17.479081  7318.000000         1.018717        0.999809          1.017295
# 3  17.115744  7322.880000         1.003778        0.991443          0.998600
# 4  16.755815  7333.164800         1.001818        0.996706          0.998491
#
#    time_to_chart_return  crypto_index
# 0              0.002718   1002.717853
# 1              0.006065   1008.799049
# 2              0.017234   1026.185154
# 3             -0.001396   1024.752845
# 4             -0.001509   1023.206387
#
# [5 rows x 90 columns]

# %%
df.columns
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'quote_asset_volumne', 'number_of_trades',
#        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore',
#        'formatted_open_time', 'formatted_close_time', 'upper_shadow',
#        'lower_shadow', 'real_body', 'CDLINVERTEDHAMMER', 'CDLHAMMER',
#        'CDLPIERCING', 'CDLMORNINGSTAR', 'CDLSHOOTINGSTAR', 'CDLHANGINGMAN',
#        'CDLDARKCLOUDCOVER', 'CDLEVENINGSTAR', 'CDLENGULFING',
#        'CDLENGULFINGBULLISH', 'CDLENGULFINGBEARISH', 'CDLINVERTEDHAMMER_NEW',
#        'CDLHAMMER_NEW', 'CDLPIERCING_NEW', 'CDLMORNINGSTAR_NEW',
#        'CDLENGULFINGBULLISH_NEW', 'CDLSHOOTINGSTAR_NEW', 'CDLHANGINGMAN_NEW',
#        'CDLDARKCLOUDCOVER_NEW', 'CDLEVENINGSTAR_NEW',
#        'CDLENGULFINGBEARISH_NEW', 'MA5', 'MA10', 'MA20', 'MA60', 'MA120',
#        'volume_MA5', 'volume_MA10', 'volume_MA20', 'SMA5', 'SMA10', 'SMA20',
#        'SMA60', 'SMA120', 'volume_SMA5', 'volume_SMA10', 'volume_SMA20',
#        'WMA5', 'WMA10', 'WMA20', 'WMA60', 'WMA120', 'volume_WMA5',
#        'volume_WMA10', 'volume_WMA20', 'EMA5', 'EMA10', 'EMA20', 'EMA60',
#        'EMA120', 'volume_EMA5', 'volume_EMA10', 'volume_EMA20', 'WILLR_14',
#        'NATR_14', 'PPO_12_26', 'CCI_14', 'ADX_14', 'ADXR_14', 'MACD_12_26_9',
#        'RSI_14', 'BBANDS_U', 'BBANDS_M', 'BBANDS_L', 'AD', 'ATR', 'HT_DC',
#        'SAR', 'ratio_high_open', 'ratio_low_open', 'ratio_close_open',
#        'time_to_chart_return', 'crypto_index'],
#       dtype='object')

# %%
#converting Date Column to DateTime Type
df['Date'] = pd.to_datetime(df['formatted_open_time'])
df.dtypes
# Out:
# open_time                        int64
# open                           float64
# high                           float64
# low                            float64
# close                          float64
#                              ...
# ratio_low_open                 float64
# ratio_close_open               float64
# time_to_chart_return           float64
# crypto_index                   float64
# Date                    datetime64[ns]
# Length: 91, dtype: object

# %%
#setting the column as index
df.set_index('Date', inplace=True)
df.head()
# Out:
#                          open_time     open     high      low    close  \
# Date
# 2020-01-06 00:00:00  1578268800000  7357.64  7384.72  7346.76  7378.75
# 2020-01-06 01:00:00  1578272400000  7378.97  7426.82  7368.55  7423.50
# 2020-01-06 02:00:00  1578276000000  7423.06  7562.00  7421.64  7551.44
# 2020-01-06 03:00:00  1578279600000  7551.47  7580.00  7486.85  7540.90
# 2020-01-06 04:00:00  1578283200000  7540.90  7554.61  7516.06  7529.52
#
#                           volume     close_time  quote_asset_volumne  \
# Date
# 2020-01-06 00:00:00  1358.867787  1578272399999         1.000665e+07
# 2020-01-06 01:00:00  1630.227541  1578275999999         1.204807e+07
# 2020-01-06 02:00:00  5819.256972  1578279599999         4.366371e+07
# 2020-01-06 03:00:00  4769.906356  1578283199999         3.593969e+07
# 2020-01-06 04:00:00  1554.582461  1578286799999         1.171094e+07
#
#                      number_of_trades  taker_buy_base_asset_volume  ...  \
# Date                                                                ...
# 2020-01-06 00:00:00             10399                   712.183975  ...
# 2020-01-06 01:00:00             14099                   917.223564  ...
# 2020-01-06 02:00:00             38256                  3402.178628  ...
# 2020-01-06 03:00:00             27817                  2222.120771  ...
# 2020-01-06 04:00:00             13475                   854.354945  ...
#
#                         BBANDS_L            AD        ATR      HT_DC  \
# Date
# 2020-01-06 00:00:00  7358.112084  19912.415403  42.216983  18.324288
# 2022-09-29 22:00:00          1.001269              0.001334   2643.936810
# 2022-09-29 23:00:00          1.007014              0.006961   2662.342110
# 2022-09-30 00:00:00          0.997693             -0.002356   2656.069305
#
# [23922 rows x 90 columns]

# %%
window_size = 5
start_date_id = int(df_selected_columns.index.get_loc('2021-01-06 00:00:00'))
mid_date_id = int(df_selected_columns.index.get_loc('2022-03-30 00:00:00'))
end_date_id = int(df_selected_columns.index.get_loc('2022-09-30 00:00:00'))

# %%
print(f'start_date_id:{start_date_id}')
print(f'mid_date_id:{mid_date_id}')
print(f'end_date_id:{end_date_id}')
# Out:
# start_date_id:8766
# mid_date_id:19505
# end_date_id:23921

# %%
print(f'mid_date_id - start_date_id: {mid_date_id - start_date_id}')
print(f'end_date_id - mid_date_id: {end_date_id - mid_date_id}')
print(f'end_date_id - start_date_id: {end_date_id - start_date_id}')
# Out:
# mid_date_id - start_date_id: 10739
# end_date_id - mid_date_id: 4416
# end_date_id - start_date_id: 15155

# %%
df_selected_columns.shape
# Out:
# (23922, 90)

# %%
# check prices
#df_selected_columns.loc[:, 'close'].to_numpy()[start_date_id-window_size:mid_date_id]

# %%
#df_selected_columns.loc[:, 'close'].to_numpy()[start_date_id - window_size + 6]

# %%
def my_process_data(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'close'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['CCI_14', 'ADX_14', 'ADXR_14', 'MACD_12_26_9', 'RSI_14']].to_numpy()[start:end]
    return prices, signal_features


class MyEnv(StocksEnvLogBLSH):
    _process_data = my_process_data

# %%
#passing the data and creating our environment
env = MyEnv(df=df_selected_columns, frame_bound=(start_date_id,mid_date_id), window_size=window_size)

# %%
#running the test environment
state = env.reset()
while True: 
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward_cash': 202.03145804747325, 'total_profit_percentage': 1.2020314580474767, 'num_of_trades': 3627.0}

# %%
#setting up our environment for training 
env_maker = lambda: MyEnv(df=df_selected_columns, frame_bound=(start_date_id,mid_date_id), window_size=window_size)
env = DummyVecEnv([env_maker])

#Applying the Trading RL Algorithm
model = A2C('MlpPolicy', env, verbose=1) 
 
#setting the learning timesteps
#model.learn(total_timesteps=1000)
model.learn(total_timesteps=(mid_date_id - start_date_id))
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 993      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.848   |
# |    explained_variance | -36.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.387   |
# |    value_loss         | 0.261    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1005     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.62    |
# |    explained_variance | -109     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0065  |
# |    value_loss         | 0.0142   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1011      |
# |    iterations         | 300       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -0.404    |
# |    explained_variance | -1.68e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | 0.0111    |
# |    value_loss         | 0.0113    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1018     |
# |    iterations         | 400      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.451   |
# |    explained_variance | 0.00858  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 6.06     |
# |    value_loss         | 49.1     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1005      |
# |    iterations         | 500       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -0.574    |
# |    explained_variance | -2.5e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -4.89e+04 |
# |    value_loss         | 1.37e+09  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 993      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.316   |
# |    explained_variance | -487     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0475   |
# |    value_loss         | 0.011    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 987      |
# |    iterations         | 700      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.36    |
# |    explained_variance | -25.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.00256  |
# |    value_loss         | 0.00179  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 977       |
# |    iterations         | 800       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.254    |
# |    explained_variance | -62       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.000508 |
# |    value_loss         | 0.00012   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 962       |
# |    iterations         | 900       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.971    |
# |    explained_variance | -7.23e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -0.0639   |
# |    value_loss         | 0.0718    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 949       |
# |    iterations         | 1000      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.158    |
# |    explained_variance | -5.04e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.0267    |
# |    value_loss         | 0.021     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 1100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.282   |
# |    explained_variance | -316     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.00311  |
# |    value_loss         | 0.00168  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 927      |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.739   |
# |    explained_variance | -866     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.003   |
# |    value_loss         | 0.0284   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 916      |
# |    iterations         | 1300     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.189   |
# |    explained_variance | 0.000146 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -31.2    |
# |    value_loss         | 2.75e+06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 906       |
# |    iterations         | 1400      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.413    |
# |    explained_variance | -1.27e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.284     |
# |    value_loss         | 0.0493    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 895       |
# |    iterations         | 1500      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.679    |
# |    explained_variance | -2.19e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -0.0763   |
# |    value_loss         | 0.0666    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 887       |
# |    iterations         | 1600      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.461    |
# |    explained_variance | -1.18e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.0332   |
# |    value_loss         | 0.00496   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 877       |
# |    iterations         | 1700      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.431    |
# |    explained_variance | -4.05e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -0.0181   |
# |    value_loss         | 0.000509  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 1800     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.452   |
# |    explained_variance | -380     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.0845  |
# |    value_loss         | 0.00995  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 857      |
# |    iterations         | 1900     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.101   |
# |    explained_variance | -78.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.000523 |
# |    value_loss         | 0.000927 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 849      |
# |    iterations         | 2000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.538   |
# |    explained_variance | -314     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0206   |
# |    value_loss         | 0.0153   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 840       |
# |    iterations         | 2100      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.198    |
# |    explained_variance | -1.88e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.000234 |
# |    value_loss         | 0.00204   |
# -------------------------------------

# %%
#Setting up the Agent Environment
env = MyEnv(df=df_selected_columns, frame_bound=(mid_date_id,end_date_id), window_size=window_size)
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward_cash': -353.5222556922425, 'total_profit_percentage': 0.6464777443077573, 'num_of_trades': 349.0}

# %%
#Plotting our Model for Trained Trades
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()

# %%
qs.extend_pandas()

start_index = mid_date_id
end_index = end_date_id

net_worth = pd.Series(env.history['total_profit_percentage'], index=df_selected_columns.index[start_index+1:end_index])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)
qs.reports.html(returns, output='a2c_quantstats.html')
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2022-03-30
# End Period                 2022-09-29
# Risk-Free Rate             0.0%
# Time in Market             4.0%
#
# Cumulative Return          -35.35%
# CAGR﹪                     -58.11%
#
# Sharpe                     -0.22
# Prob. Sharpe Ratio         13.34%
# Smart Sharpe               -0.22
# Sortino                    -0.23
# Smart Sortino              -0.23
# Sortino/√2                 -0.16
# Smart Sortino/√2           -0.16
# Omega                      0.73
#
# Max Drawdown               -42.8%
# Longest DD Days            174
# Volatility (ann.)          9.24%
# Calmar                     -1.36
# Skew                       -28.05
# Kurtosis                   1142.31
#
# Expected Daily %           -0.01%
# Expected Monthly %         -6.04%
# Expected Yearly %          -35.35%
# Kelly Criterion            -20.33%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -0.97%
# Expected Shortfall (cVaR)  -0.97%
#
# Max Consecutive Wins       1
# Max Consecutive Losses     1
# Gain/Pain Ratio            -0.3
# Gain/Pain (1M)             -0.84
#
# Payoff Ratio               0.62
# Profit Factor              0.73
# Common Sense Ratio         -
# CPC Index                  0.24
# Tail Ratio                 -
# Outlier Win Ratio          30.32
# Outlier Loss Ratio         0.22
#
# MTD                        6.66%
# 3M                         0.06%
# 6M                         -35.35%
# YTD                        -35.35%
# 1Y                         -35.35%
# 3Y (ann.)                  -58.11%
# 5Y (ann.)                  -58.11%
# 10Y (ann.)                 -58.11%
# All-time (ann.)            -58.11%
#
# Best Day                   5.26%
# Worst Day                  -26.3%
# Best Month                 6.66%
# Worst Month                -24.66%
# Best Year                  -35.35%
# Worst Year                 -35.35%
#
# Avg. Drawdown              -22.75%
# Avg. Drawdown Days         90
# Recovery Factor            -0.83
# Ulcer Index                0.29
# Serenity Index             -0.01
#
# Avg. Up Month              3.4%
# Avg. Down Month            -9.16%
# Win Days %                 54.02%
# Win Month %                28.57%
# Win Quarter %              66.67%
# Win Year %                 0.0%
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2022-04-08  2022-09-16  2022-09-29   174    -42.797822        -42.451553
# 2  2022-03-30  2022-04-01  2022-04-05     5     -2.696776         -1.522579
# <h4>Strategy Visualization</h4>
