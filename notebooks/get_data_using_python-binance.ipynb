# %% [markdown]
# # Get Data using python-binance

# %% [markdown]
# ## Import relevant libraries

# %%
from binance.client import Client
from dotenv import load_dotenv
import os
import pandas as pd
import datetime

# %% [markdown]
# ## Set some 'global' parameters

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Get the data

# %% [markdown]
# ### Create the client

# %%
client = Client(os.environ["BINANCE_API_KEY"], os.environ["BINANCE_SECRET_KEY"])

# %% [markdown]
# ### Parameters

# %%
asset_ticket = "BTCUSDT"
# timestamp = Client.KLINE_INTERVAL_1MINUTE
# timestamp = Client.KLINE_INTERVAL_5MINUTE
timestamp = Client.KLINE_INTERVAL_15MINUTE
start_date = "1 Jan, 2020"
end_date = "31 Dec, 2021"

# %% [markdown]
# ### Get the data

# %%
klines = client.get_historical_klines(asset_ticket, timestamp, start_date, end_date)

# %% [markdown]
# ### Convert list of lists to Pandas Datafrae

# %%
df_klines = pd.DataFrame(klines, columns = ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volumne', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])

# %% [markdown]
# ### Check the data

# %%
df_klines.sample(5)
# Out:
#            open_time            open            high             low  \
# 15055  1591426800000   9610.00000000   9640.00000000   9610.00000000
# 11205  1587961800000   7706.00000000   7734.97000000   7705.00000000
# 67494  1638714600000  48959.48000000  49136.14000000  48869.13000000
# 16404  1592640900000   9299.31000000   9314.32000000   9293.46000000
# 36287  1610569800000  35937.17000000  36062.26000000  35704.21000000
#
#                 close         volume     close_time quote_asset_volumne  \
# 15055   9627.56000000   285.15201300  1591427699999    2745040.18070314
# 11205   7734.19000000   374.84897300  1587962699999    2894882.25116354
# 67494  49043.09000000   377.54722000  1638715499999   18500735.95946240
# 16404   9304.59000000   388.41402400  1592641799999    3613479.24828892
# 36287  35964.32000000  1412.41040700  1610570699999   50661991.60717947
#
#        number_of_trades taker_buy_base_asset_volume  \
# 15055              4488                121.52074200
# 11205              5243                210.76442800
# 67494             14442                203.28506000
# 16404              4110                187.28149500
# 36287             31324                721.85589800
#
#       taker_buy_quote_asset_volume ignore
# 15055             1169600.01132368      0
# 11205             1627836.82764014      0
# 67494             9961108.42743890      0
# 16404             1742066.51353627      0
# 36287            25896865.85503310      0

# %%
df_klines.describe()
# Out:
#           open_time    close_time  number_of_trades
# count  6.993300e+04  6.993300e+04      69933.000000
# mean   1.609381e+12  1.609382e+12      14073.070854
# std    1.820805e+10  1.820805e+10      12105.703394
# min    1.577837e+12  1.577838e+12          0.000000
# 25%    1.593625e+12  1.593625e+12       6511.000000
# 50%    1.609381e+12  1.609382e+12      10878.000000
# 75%    1.625151e+12  1.625152e+12      17840.000000
# max    1.640909e+12  1.640910e+12     340874.000000

# %%
df_klines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69933 entries, 0 to 69932
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   open_time                     69933 non-null  int64
#  1   open                          69933 non-null  object
#  2   high                          69933 non-null  object
#  3   low                           69933 non-null  object
#  4   close                         69933 non-null  object
#  5   volume                        69933 non-null  object
#  6   close_time                    69933 non-null  int64
#  7   quote_asset_volumne           69933 non-null  object
#  8   number_of_trades              69933 non-null  int64
#  9   taker_buy_base_asset_volume   69933 non-null  object
#  10  taker_buy_quote_asset_volume  69933 non-null  object
#  11  ignore                        69933 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 6.4+ MB

# %%
print(df_klines.isnull().sum())
# Out:
# open_time                       0
# open                            0
# high                            0
# low                             0
# close                           0
# volume                          0
# close_time                      0
# quote_asset_volumne             0
# number_of_trades                0
# taker_buy_base_asset_volume     0
# taker_buy_quote_asset_volume    0
# ignore                          0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Copy original data

# %%
df_klines_copy = df_klines.copy()

# %% [markdown]
# ### Convert 'object' to float pandas

# %%
df_klines_copy['open'] = pd.to_numeric(df_klines_copy['open'])
df_klines_copy['high'] = pd.to_numeric(df_klines_copy['high'])
df_klines_copy['low'] = pd.to_numeric(df_klines_copy['low'])
df_klines_copy['close'] = pd.to_numeric(df_klines_copy['close'])
df_klines_copy['volume'] = pd.to_numeric(df_klines_copy['volume'])

# %% [markdown]
# ### Convert the 'open_time' and 'close_time' to a Pandas DataTime format

# %%
df_klines_copy['formatted_open_time'] = pd.to_datetime(df_klines_copy['open_time'], infer_datetime_format=True, unit="ms")
df_klines_copy['formatted_close_time'] = pd.to_datetime(df_klines_copy['close_time'], infer_datetime_format=True, unit="ms")

# %% [markdown]
# ### Check the data - head and tail

# %%
df_klines_copy.head()
# Out:
#        open_time     open     high      low    close      volume  \
# 0  1577836800000  7195.24  7196.25  7178.20  7180.97  202.942868
# 1  1577837700000  7180.97  7186.40  7175.47  7178.45  128.242654
# 2  1577838600000  7178.19  7185.44  7176.23  7179.56   83.487458
# 3  1577839500000  7179.35  7183.98  7175.46  7177.02   97.141921
# 4  1577840400000  7176.47  7194.04  7175.71  7190.86  103.520522
#
#       close_time quote_asset_volumne  number_of_trades  \
# 0  1577837699999    1458244.89963462              2452
# 1  1577838599999     920702.74707886              1948
# 2  1577839499999     599479.15280528              1580
# 3  1577840399999     697429.77996667              1660
# 4  1577841299999     744089.10404112              1588
#
#   taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore  \
# 0                 76.96204100              553069.53492894      0
# 1                 58.38911000              419226.47144695      0
# 2                 43.82237400              314667.32107150      0
# 3                 46.97960100              337325.86220298      0
# 4                 56.25137800              404330.49838606      0
#
#   formatted_open_time    formatted_close_time
# 0 2020-01-01 00:00:00 2020-01-01 00:14:59.999
# 1 2020-01-01 00:15:00 2020-01-01 00:29:59.999
# 2 2020-01-01 00:30:00 2020-01-01 00:44:59.999
# 3 2020-01-01 00:45:00 2020-01-01 00:59:59.999
# 4 2020-01-01 01:00:00 2020-01-01 01:14:59.999

# %%
df_klines_copy.tail()
# Out:
#            open_time      open     high       low     close     volume  \
# 69928  1640905200000  47084.88  47240.0  46987.99  47110.36  235.14202
# 69929  1640906100000  47110.36  47242.6  47040.81  47122.27  179.83497
# 69930  1640907000000  47122.28  47160.0  46940.96  47092.12  198.46904
# 69931  1640907900000  47092.12  47177.3  47044.16  47120.87   96.74091
# 69932  1640908800000  47120.88  47500.0  47080.00  47296.76  379.28228
#
#           close_time quote_asset_volumne  number_of_trades  \
# 69928  1640906099999   11074079.31994670              9099
# 69929  1640906999999    8478394.92445030              7332
# 69930  1640907899999    9337706.99817830              7905
# 69931  1640908799999    4557887.24475770              5540
# 69932  1640909699999   17939187.98379330             12653
#
#       taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore  \
# 69928                128.88618000             6070838.56666560      0
# 69929                 78.48148000             3700971.98906070      0
# 69930                 86.94927000             4089632.56299240      0
# 69931                 50.11043000             2360849.76283950      0
# 69932                196.76069000             9309185.94226890      0
#
#       formatted_open_time    formatted_close_time
# 69928 2021-12-30 23:00:00 2021-12-30 23:14:59.999
# 69929 2021-12-30 23:15:00 2021-12-30 23:29:59.999
# 69930 2021-12-30 23:30:00 2021-12-30 23:44:59.999
# 69931 2021-12-30 23:45:00 2021-12-30 23:59:59.999
# 69932 2021-12-31 00:00:00 2021-12-31 00:14:59.999

# %% [markdown]
# ### Create the 'upper_shadow', 'lower_shadow' and 'real_body' values (to compose the CURL)

# %%
def create_curl_values(df):
    try:
        results_upper_shadow = []
        results_lower_shadow = []
        results_real_body = []
        for index, row in df.iterrows():
            if row.open > row.close:
                results_upper_shadow.append(row.high - row.open)
                results_lower_shadow.append(row.close - row.low)
                results_real_body.append(row.open - row.close)
            else:
                results_upper_shadow.append(row.high - row.close)
                results_lower_shadow.append(row.open - row.low)
                results_real_body.append(row.close - row.open)

        df['upper_shadow'] = results_upper_shadow
        df['lower_shadow'] = results_lower_shadow
        df['real_body'] = results_real_body

        return df

    except Exception as e:
        print(row.formatted_open_time)
        print(e)

# %%
df_klines_copy = create_curl_values(df_klines_copy)

# %% [markdown]
# ### Check the data - head and tail

# %%
df_klines_copy.head()
# Out:
#        open_time     open     high      low    close      volume  \
# 0  1577836800000  7195.24  7196.25  7178.20  7180.97  202.942868
# 1  1577837700000  7180.97  7186.40  7175.47  7178.45  128.242654
# 2  1577838600000  7178.19  7185.44  7176.23  7179.56   83.487458
# 3  1577839500000  7179.35  7183.98  7175.46  7177.02   97.141921
# 4  1577840400000  7176.47  7194.04  7175.71  7190.86  103.520522
#
#       close_time quote_asset_volumne  number_of_trades  \
# 0  1577837699999    1458244.89963462              2452
# 1  1577838599999     920702.74707886              1948
# 2  1577839499999     599479.15280528              1580
# 3  1577840399999     697429.77996667              1660
# 4  1577841299999     744089.10404112              1588
#
#   taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore  \
# 0                 76.96204100              553069.53492894      0
# 1                 58.38911000              419226.47144695      0
# 2                 43.82237400              314667.32107150      0
# 3                 46.97960100              337325.86220298      0
# 4                 56.25137800              404330.49838606      0
#
#   formatted_open_time    formatted_close_time  upper_shadow  lower_shadow  \
# 0 2020-01-01 00:00:00 2020-01-01 00:14:59.999          1.01          2.77
# 1 2020-01-01 00:15:00 2020-01-01 00:29:59.999          5.43          2.98
# 2 2020-01-01 00:30:00 2020-01-01 00:44:59.999          5.88          1.96
# 3 2020-01-01 00:45:00 2020-01-01 00:59:59.999          4.63          1.56
# 4 2020-01-01 01:00:00 2020-01-01 01:14:59.999          3.18          0.76
#
#    real_body
# 0      14.27
# 1       2.52
# 2       1.37
# 3       2.33
# 4      14.39

# %%
df_klines_copy.tail()
# Out:
#            open_time      open     high       low     close     volume  \
# 69928  1640905200000  47084.88  47240.0  46987.99  47110.36  235.14202
# 69929  1640906100000  47110.36  47242.6  47040.81  47122.27  179.83497
# 69930  1640907000000  47122.28  47160.0  46940.96  47092.12  198.46904
# 69931  1640907900000  47092.12  47177.3  47044.16  47120.87   96.74091
# 69932  1640908800000  47120.88  47500.0  47080.00  47296.76  379.28228
#
#           close_time quote_asset_volumne  number_of_trades  \
# 69928  1640906099999   11074079.31994670              9099
# 69929  1640906999999    8478394.92445030              7332
# 69930  1640907899999    9337706.99817830              7905
# 69931  1640908799999    4557887.24475770              5540
# 69932  1640909699999   17939187.98379330             12653
#
#       taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore  \
# 69928                128.88618000             6070838.56666560      0
# 69929                 78.48148000             3700971.98906070      0
# 69930                 86.94927000             4089632.56299240      0
# 69931                 50.11043000             2360849.76283950      0
# 69932                196.76069000             9309185.94226890      0
#
#       formatted_open_time    formatted_close_time  upper_shadow  lower_shadow  \
# 69928 2021-12-30 23:00:00 2021-12-30 23:14:59.999        129.64         96.89
# 69929 2021-12-30 23:15:00 2021-12-30 23:29:59.999        120.33         69.55
# 69930 2021-12-30 23:30:00 2021-12-30 23:44:59.999         37.72        151.16
# 69931 2021-12-30 23:45:00 2021-12-30 23:59:59.999         56.43         47.96
# 69932 2021-12-31 00:00:00 2021-12-31 00:14:59.999        203.24         40.88
#
#        real_body
# 69928      25.48
# 69929      11.91
# 69930      30.16
# 69931      28.75
# 69932     175.88

# %% [markdown]
# ## Export the Data

# %% [markdown]
# ### Export parameters

# %%
export_path = "../data"
export_filename = "binance" + \
                  "_" + asset_ticket + \
                  "_" + timestamp + \
                  "_from_" + datetime.datetime.strptime(start_date,'%d %b, %Y').strftime('%Y_%m_%d') + \
                  "_to_" + datetime.datetime.strptime(end_date,'%d %b, %Y').strftime('%Y_%m_%d')
export_extension = ".csv"
full_export_path = os.path.join(export_path, export_filename + export_extension)

# %% [markdown]
# ### Export

# %%
df_klines_copy.to_csv(full_export_path, index=False)
